# %%
## read the data
import scipy.io
data = scipy.io.loadmat('/Users/jinyanwei/Desktop/BP_Model/Data/Cuffless_BP_Estimation/part_1.mat')

# %%
fs =125 # Sample rate in Hz

import scipy.signal as signal
def chebyshev_filter(signal):
    # Define the filter order and cutoff frequency
    order = 4
    cutoff_freq = 20  # Cutoff frequency in Hz
    # Create the Chebyshev low-pass filter
    b, a = signal.cheby1(order, 0.5, cutoff_freq / (fs / 2), 'low', analog=False)
    return signal.lfilter(b, a, signal)

from scipy.signal import butter, filtfilt
def butter_filter(signal):
    fs = 125  # Sample rate
    cutoff = 5  # Cutoff frequency in Hz
    # Design the Butterworth low-pass filter
    nyquist = 0.5 * fs
    cutoff_norm = cutoff / nyquist
    b, a = butter(4, cutoff_norm, btype='low')
    return filtfilt(b, a, signal)

import numpy as np
def straighten_ecg(ecg_signal):
    detrended_ecg = np.subtract(ecg_signal, np.mean(ecg_signal))
    return detrended_ecg
    
import numpy as np
def normalize_sinal(ppg):
# Assuming ppg_signal and ecg_signal are your original PPG and ECG signals
    ppg_min = np.min(ppg)
    ppg_max = np.max(ppg)
    normalized_ppg = (ppg - ppg_min) / (ppg_max - ppg_min)
    return normalized_ppg
def standard_signal(bp): 
    return (bp - np.mean(bp)) / np.std(bp)
def inverse_standard_signal(bp_ori, bp_est):
    mean = np.mean(bp_ori)
    std = np.std(bp_ori)
    return (bp_est * std) + mean

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
def align_ppgbp_segment(ppg_signal, bp_signal1, bp_signal2, ecg_signal, show=0): ## ppg_signal = ppg_normalized, bp_signal = bp_normalized, ecg_signal = ecg_normalized; get ppg_aligned, bp_aligned
    ppg_peaks, _ = find_peaks(ppg_signal, height=0.5)  # Adjust the height threshold as needed
    bp_peaks, _ = find_peaks(bp_signal1, height=0.4)
    ecg_peaks, _ = find_peaks(ecg_signal, height=0.65)
    #print(f'ppg peaks: {len(ppg_peaks)} {ppg_peaks}')
    #print(f'ecg peaks: {len(ecg_peaks)} {ecg_peaks}')

    first_ecg_peak = ecg_peaks[0]
    #print(f'first ecg peak: {first_ecg_peak}')
    indices_ppg = np.argwhere(ppg_peaks[:10] > first_ecg_peak)
    first_ppg_peak = ppg_peaks[int(indices_ppg[0])]
    #print(f'first ppg peak: {first_ppg_peak}')
    indices_bp = np.argwhere(bp_peaks[:10] > first_ecg_peak)
    first_bp_peak = bp_peaks[int(indices_bp[0])]
    #print(f'first bp peak: {first_bp_peak}')
    ppg_bp_peaks_subtraction = abs(bp_peaks[int(indices_bp[0]):int(indices_bp[0])+20] - ppg_peaks[int(indices_ppg[0]):int(indices_ppg[0])+20])
    #print(ppg_bp_peaks_subtraction)
    distance_ppgbp = np.bincount(ppg_bp_peaks_subtraction).argmax()
    #print(move_distance)
    #print(bp_peaks[int(indices_bp[0]):int(indices_bp[0])+20] - ppg_peaks[int(indices_ppg[0]):int(indices_ppg[0])+20])
    #print(f'distance:{distance_ppgbp}')
    if first_bp_peak > first_ppg_peak:
        bp_aligned = bp_signal1[distance_ppgbp:]
        bp_ori_aligned = bp_signal2[distance_ppgbp:]
        ppg_aligned = ppg_signal
    elif first_bp_peak < first_ppg_peak:
        bp_aligned = bp_signal1
        bp_ori_aligned = bp_signal2
        ppg_aligned = ppg_signal[distance_ppgbp:]
    else:
        bp_aligned = bp_signal1
        bp_ori_aligned = bp_signal2
        ppg_aligned = ppg_signal
    #print(f'ppg len: {len(ppg_aligned)}')
    #print(f'bp len: {len(bp_aligned)}')
    min_len = min(len(bp_aligned), len(ppg_aligned))
    ppg_aligned = ppg_aligned[:min_len]
    bp_aligned = bp_aligned[:min_len]
    bp_ori_aligned = bp_ori_aligned[:min_len]
    ecg_aligned = ecg_signal[:min_len]
    #print(ecg_aligned)
    ppg_segmented = ppg_aligned[:first_ecg_peak-5]
    bp_segmented = bp_aligned[:first_ecg_peak-5]
    bp_ori_segmented = bp_ori_aligned[:first_ecg_peak-5]
    ecg_segmented = ecg_aligned[:first_ecg_peak-5]

    for ecgi in range(len(ecg_peaks)-1):
        one_ppg_peak, _ = find_peaks(ppg_aligned[ecg_peaks[ecgi]-5:ecg_peaks[ecgi + 1]-5], height=0.5)
        #print(ecg_peaks[ecgi], one_ppg_peak)
        if len(one_ppg_peak) == 1:
            ppg_segmented = np.concatenate((ppg_segmented, ppg_aligned[ecg_peaks[ecgi]-5:ecg_peaks[ecgi + 1]-5]))
            bp_segmented = np.concatenate((bp_segmented, bp_aligned[ecg_peaks[ecgi]-5:ecg_peaks[ecgi + 1]-5]))
            bp_ori_segmented = np.concatenate((bp_ori_segmented, bp_ori_aligned[ecg_peaks[ecgi]-5:ecg_peaks[ecgi + 1]-5]))
            ecg_segmented = np.concatenate((ecg_segmented, ecg_aligned[ecg_peaks[ecgi]-5:ecg_peaks[ecgi + 1]-5]))

    if show == 1:
        plt.figure(figsize=(30, 6))
        plt.plot(ppg_signal, label='PPG')
        #plt.plot(bp_signal1, label='BP')
        #plt.plot(ecg_signal, label='ECG')
        plt.scatter(ppg_peaks, ppg_signal[ppg_peaks], color='c', marker='o', label='Aligned PPG Peaks')
        #plt.scatter(bp_peaks, bp_signal1[bp_peaks], color='orange', marker='o', label='Aligned BP Peaks')
        #plt.scatter(ecg_peaks, ecg_signal[ecg_peaks], color='green', marker='o', label='Aligned BP Peaks')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.legend()
        plt.show()

        plt.figure(figsize=(30, 6))
        plt.plot(ppg_segmented, label='PPG')
        #plt.plot(bp_segmented, label='BP')
        #plt.plot(ecg_segmented, label='ECG')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.legend()
        plt.show()

    return ppg_segmented, bp_segmented, bp_ori_segmented, ecg_segmented

import numpy as np
def get_feautres(ppg_signal, bp_signal1, bp_signal2, ecg_signal):
    ori_ecg_peaks, _ = find_peaks(ecg_signal)
    r_peaks = np.array([ecg_peak for ecg_peak in ori_ecg_peaks if ecg_signal[ecg_peak] > 0.65])
    #print(f'r_peaks: {len(r_peaks)} {r_peaks}')
    r_peak_amplitudes = (ecg_signal[r_peaks]).tolist()
    r_peak_amplitudes = r_peak_amplitudes[:-1]
    #print(f'r_peak_amplitudes: {len(r_peak_amplitudes)} {r_peak_amplitudes}')
    r_peak_intervals = (np.diff(r_peaks) / fs).tolist()
    #print(f'r_peak_intervals: {len(r_peak_intervals)} {r_peak_intervals}')
    # calculate low peak, s-peak
    low_peak_amplitudes, r_to_low_peak_amplitudes, s_peak_amplitudes= [], [], []
    low_peaks, s_peaks = [], []
    for i in range(len(r_peaks) - 1):
        r_peak = r_peaks[i]
        next_r_peak = r_peaks[i + 1]
        low_peak_amplitude = np.min(ecg_signal[r_peak:next_r_peak])
        r_to_low_peak_amplitude = ecg_signal[r_peak]-low_peak_amplitude
        low_peak_amplitudes.append(low_peak_amplitude)
        r_to_low_peak_amplitudes.append(r_to_low_peak_amplitude)
        low_peak = r_peak + np.argmin(ecg_signal[r_peak:next_r_peak])
        low_peaks.append(low_peak)
        s_peak_amplitude = np.min(ecg_signal[r_peak:low_peak])
        s_peak_amplitudes.append(s_peak_amplitude)
        s_peak = r_peak + np.argmin(ecg_signal[r_peak:low_peak])
        s_peaks.append(s_peak)   
    #print(f'low peaks: {len(low_peaks)} {low_peaks}')  
    #print(f's peaks: {len(s_peaks)} {s_peaks}')  
    # T-Wave Amplitude Calculation
    r_peaks = np.insert(r_peaks, 0, 0) #the first t-peak is before the R-peak
    t_wave_amplitudes, q_wave_amplitudes = [], []
    t_peaks, q_peaks = [], []
    for i in range(len(r_peaks) - 1):
        r_peak = r_peaks[i]
        next_r_peak = r_peaks[i + 1]
        t_wave_amplitude = np.max(ecg_signal[r_peak:next_r_peak])
        t_wave_amplitudes.append(t_wave_amplitude)
        t_peak = r_peak + np.argmax(ecg_signal[r_peak:next_r_peak])
        t_peaks.append(t_peak)
        q_wave_amplitude = np.min(ecg_signal[t_peak:next_r_peak])
        q_wave_amplitudes.append(q_wave_amplitude)
        q_peak = r_peak + np.argmin(ecg_signal[t_peak:next_r_peak])
        q_peaks.append(q_peak)

    t_wave_amplitudes = t_wave_amplitudes[:-1]
    q_wave_amplitudes = q_wave_amplitudes[:-1]
    #print(f't peaks: {len(t_peaks)} {t_peaks}')  
    #print(f'q peaks: {len(q_peaks)} {q_peaks}')  
    
    # QRS interval
    r_peaks = np.array([ecg_peak for ecg_peak in ori_ecg_peaks if ecg_signal[ecg_peak] > 0.65])
    qrs_intervals = []
    for i in range(len(r_peaks)-1):
        qrs_interval = (ecg_signal[s_peaks[i]] - ecg_signal[q_peaks[i]]) / fs
        qrs_intervals.append(abs(qrs_interval))
    #print(f'qrs_intervals: {len(qrs_intervals)} {qrs_intervals}')  

    # get ppg features:
    ppg_pulses, bp_pulses, bp_ori_pulses = [], [], []
    for i in range(len(r_peaks)-1):
        ppg_pulse = ppg_signal[r_peaks[i]:r_peaks[i+1]]
        bp_pulse = bp_signal1[r_peaks[i]:r_peaks[i+1]]
        bp_ori_pulse = bp_signal2[r_peaks[i]:r_peaks[i+1]]
        ppg_pulses.append(ppg_pulse)
        bp_pulses.append(bp_pulse)
        bp_ori_pulses.append(bp_ori_pulse)
    #print(f'bp pulses: {bp_pulses}')
    ppg_pulse_amplitude = [np.max(pulse) - np.min(pulse) for pulse in ppg_pulses]
    ppg_pulse_width = [pulse.shape[0]/fs for pulse in ppg_pulses]
    ppg_high_to_low_interval = [np.argmin(pulse)/fs for pulse in ppg_pulses]
    ppg_slope_change_std = [np.std(np.diff(pulse)) for pulse in ppg_pulses]

    sbp = [np.max(pulse) for pulse in bp_pulses]
    dbp = [np.min(pulse) for pulse in bp_pulses]
    sbp_ori = [np.max(pulse) for pulse in bp_ori_pulses]
    dbp_ori = [np.min(pulse) for pulse in bp_ori_pulses]
    
    return sbp, dbp, sbp_ori, dbp_ori, ppg_pulse_amplitude, ppg_pulse_width, ppg_high_to_low_interval, ppg_slope_change_std, t_wave_amplitudes, q_wave_amplitudes, r_peak_amplitudes, s_peak_amplitudes, low_peak_amplitudes, qrs_intervals, r_to_low_peak_amplitudes, r_peak_intervals

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
import pandas as pd
def create_sequences(X, y, time_steps=4):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X.iloc[i:(i + time_steps)])
        ys.append(y.iloc[i+1])
    return np.array(Xs), np.array(ys)  

def bp_lstm_model(train_features, train_bp):
    time_steps = 4
    X_train, y_train = create_sequences(pd.DataFrame(train_features), pd.DataFrame(train_bp), time_steps)
    model = Sequential()
    model.add(LSTM(units=100, return_sequences=True, input_shape=(time_steps, 12)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=100))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=200, verbose=1)
    return model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
def gru_model(X_train, y_train):
    time_steps = 4
    X_train, y_train = create_sequences(pd.DataFrame(X_train), pd.DataFrame(y_train), time_steps)
    model = Sequential()
    model.add(GRU(units=100, return_sequences=True, input_shape=(time_steps, 12)))
    model.add(Dropout(0.2))
    model.add(GRU(units=100, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(GRU(units=100))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=300, verbose=1)
    return model

import matplotlib.pyplot as plt
def show_one(signal1):
    fig = plt.figure(figsize=(30,6))
    plt.plot(signal1)
    return plt.show()
def show_two(signal1, signal2):
    fig = plt.figure(figsize=(30,6))
    plt.plot(signal1, label='1')
    plt.plot(signal2, label='2')
    plt.legend()
    return plt.show()
def show_three(signal1, signal2, signal3):
    fig = plt.figure(figsize=(30,6))
    plt.plot(signal1, label='1')
    plt.plot(signal2, label='2')
    plt.plot(signal3, label='3')
    plt.legend()
    return plt.show()

# %%
# get all patient dataset
patients = [0, 1, 2, 3, 4, 6, 14, 15, 16, 18, 24, 35, 36, 37, 39, 40, 41, 46, 64, 66, 67, 73, 79, 80, 81, 82, 86, 87, 88, 89, 93, 94, 95, 98, 99, 100, 101, 102, 103, 104, 105, 108, 109, 110, 111, 115, 116, 117, 118, 120, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 141, 144, 149, 150, 151, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 179, 182, 184, 186, 188, 189, 192, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 206, 207, 208, 209, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 245, 246, 247, 248, 249, 251, 252, 253, 254, 255, 256, 257, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 272, 273, 277, 278, 279, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 295, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 309, 310, 311, 313, 314, 315, 316, 317, 318, 319, 320, 321, 323, 324, 327, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 377, 380, 391, 393, 394, 395, 397, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 413, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 429, 430, 431, 432, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 459, 460, 462, 463, 464, 465, 466, 470, 471, 472, 475, 480, 481, 482, 483, 484, 486, 487, 488, 490, 491, 492, 496, 497, 498, 499, 500, 502, 503, 504, 505, 507, 508, 509, 510, 512, 514, 515, 516, 520, 524, 527, 528, 529, 530, 531, 532, 533, 535, 537, 538, 539, 543, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 564, 565, 570, 576, 577, 578, 582, 590, 592, 593, 597, 599, 600, 602, 603, 604, 606, 607, 609, 612, 625, 626, 627, 628, 629, 630, 633, 634, 635, 639, 640, 641, 644, 646, 648, 653, 655, 656, 657, 658, 662, 670, 673, 674, 676, 677, 681, 682, 683, 685, 686, 687, 688, 689, 692, 693, 695, 696, 697, 698, 700, 703, 704, 705, 706, 707, 708, 709, 711, 712, 717, 719, 720, 721, 722, 723, 724, 725, 727, 729, 730, 731, 733, 734, 735, 736, 737, 741, 743, 744, 748, 749, 753, 754, 755, 756, 759, 774, 775, 776, 777, 780, 781, 783, 784, 785, 786, 787, 790, 791, 792, 794, 799, 800, 801, 802, 803, 805, 807, 808, 809, 810, 813, 820, 821, 822, 823, 828, 829, 830, 843, 845, 847, 868, 869, 922, 923, 947, 948, 949, 951, 952, 957, 959, 960, 962, 972, 975, 981, 989]
sbp500 = []
dbp500 = []
sbp_ori500 = []
dbp_ori500 = []
features500 = []
for patient in patients:
    patient_data = data['p'][0,patient]
    if len(patient_data[0]) >= 25000:
        ppg_ori = patient_data[0]
        bp_ori = patient_data[1]
        ecg_ori = patient_data[2]
        ecg_detrened = straighten_ecg(ecg_ori)
        ppg_normalized = normalize_sinal(ppg_ori)
        bp_standarded = bp_ori / 250
        ecg_normalized = normalize_sinal(ecg_detrened)
        ppg_segmented, bp_segmented, bp_ori_segmented, ecg_segmented = align_ppgbp_segment(ppg_signal = ppg_normalized, bp_signal1 = bp_standarded, bp_signal2 = bp_ori, ecg_signal = ecg_normalized, show=0)
        bps_features = get_feautres(ppg_segmented, bp_segmented, bp_ori_segmented, ecg_segmented)
        sbp = np.array(bps_features[0])
        dbp = np.array(bps_features[1])
        sbp_ori = np.array(bps_features[2])
        dbp_ori = np.array(bps_features[3])
        features = np.array(bps_features[4:])
        sbp500.append(sbp)
        dbp500.append(dbp)
        sbp_ori500.append(sbp_ori)
        dbp_ori500.append(dbp_ori)
        features500.append(features)
        print(patient)
len(sbp_ori500)

# %%
## split train and test dataset
train_sbp = sbp500[:400]
train_dbp = dbp500[:400]
train_sbp_ori = sbp_ori500[:400]
train_dbp_ori = dbp_ori500[:400]
train_features = features500[:400]
test_sbp = []
test_dbp = []
test_sbp_ori = []
test_dbp_ori = []
test_features = []

for i in range(len(sbp500)-400):
    train_sbp.append(sbp500[i+400][:int(0.2*len(sbp500[i+400]))])
    train_dbp.append(dbp500[i+400][:int(0.2*len(dbp500[i+400]))])
    train_sbp_ori.append(sbp_ori500[i+400][:int(0.2*len(sbp_ori500[i+400]))])
    train_dbp_ori.append(dbp_ori500[i+400][:int(0.2*len(dbp_ori500[i+400]))])
    train_features.append(features500[i+400][:,:int(0.2*(features500[i+400].shape[1]))])
    test_sbp.append(sbp500[i+400][int(0.2*len(sbp500[i+400])):])
    test_dbp.append(dbp500[i+400][int(0.2*len(dbp500[i+400])):])
    test_sbp_ori.append(sbp_ori500[i+400][int(0.2*len(sbp_ori500[i+400])):])
    test_dbp_ori.append(dbp_ori500[i+400][int(0.2*len(dbp_ori500[i+400])):])
    test_features.append(features500[i+400][:,int(0.2*(features500[i+400].shape[1])):])

merged_train_sbp = np.concatenate(train_sbp, axis=0)
merged_train_dbp = np.concatenate(train_dbp, axis=0)
merged_train_sbp_ori = np.concatenate(train_sbp_ori, axis=0)
merged_train_dbp_ori = np.concatenate(train_dbp_ori, axis=0)
merged_train_features = np.concatenate(train_features, axis=1)
merged_train_features = merged_train_features.T

# %%
merged_train_features.shape
# Out:
# (274358, 12)

# %%
lstm_model_sbp = bp_lstm_model(merged_train_features, merged_train_sbp)
# Out:
# Epoch 1/200
# 8574/8574 [==============================] - 63s 7ms/step - loss: 0.0084
# Epoch 2/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0071
# Epoch 3/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0064
# Epoch 4/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0058
# Epoch 5/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0051
# Epoch 6/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0046
# Epoch 7/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0042
# Epoch 8/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0040
# Epoch 9/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0038
# Epoch 10/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0036
# Epoch 11/200
# 8574/8574 [==============================] - 63s 7ms/step - loss: 0.0035
# Epoch 12/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 0.0033
# Epoch 13/200
# 8574/8574 [==============================] - 64s 7ms/step - loss: 0.0032
# Epoch 14/200
# 8574/8574 [==============================] - 66s 8ms/step - loss: 0.0031
# Epoch 15/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0031
# Epoch 16/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0030
# Epoch 17/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0029
# Epoch 18/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0029
# Epoch 19/200
# 8574/8574 [==============================] - 63s 7ms/step - loss: 0.0028
# Epoch 20/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0028
# Epoch 21/200
# 8574/8574 [==============================] - 67s 8ms/step - loss: 0.0027
# Epoch 22/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0027
# Epoch 23/200
# 8574/8574 [==============================] - 62s 7ms/step - loss: 0.0027
# Epoch 24/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0026
# Epoch 25/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0026
# Epoch 26/200
# 8574/8574 [==============================] - 62s 7ms/step - loss: 0.0026
# Epoch 27/200
# 8574/8574 [==============================] - 66s 8ms/step - loss: 0.0026
# Epoch 28/200
# 8574/8574 [==============================] - 62s 7ms/step - loss: 0.0025
# Epoch 29/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0025
# Epoch 30/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0025
# Epoch 31/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0025
# Epoch 32/200
# 8574/8574 [==============================] - 66s 8ms/step - loss: 0.0024
# Epoch 33/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0024
# Epoch 34/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0024
# Epoch 35/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0024
# Epoch 36/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0024
# Epoch 37/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0023
# Epoch 38/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0023
# Epoch 39/200
# 8574/8574 [==============================] - 64s 7ms/step - loss: 0.0023
# Epoch 40/200
# 8574/8574 [==============================] - 64s 7ms/step - loss: 0.0023
# Epoch 41/200
# 8574/8574 [==============================] - 66s 8ms/step - loss: 0.0023
# Epoch 42/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0023
# Epoch 43/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0023
# Epoch 44/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0023
# Epoch 45/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0022
# Epoch 46/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0022
# Epoch 47/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0022
# Epoch 48/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0022
# Epoch 49/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0022
# Epoch 50/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0022
# Epoch 51/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0022
# Epoch 52/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 0.0022
# Epoch 53/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0022
# Epoch 54/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0022
# Epoch 55/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0022
# Epoch 56/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0021
# Epoch 57/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0021
# Epoch 58/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0021
# Epoch 59/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0021
# Epoch 60/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0021
# Epoch 61/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0021
# Epoch 62/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 0.0021
# Epoch 63/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 0.0021
# Epoch 64/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0021
# Epoch 65/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0021
# Epoch 66/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0021
# Epoch 67/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0021
# Epoch 68/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0021
# Epoch 69/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0021
# Epoch 70/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0020
# Epoch 71/200
# 8574/8574 [==============================] - 63s 7ms/step - loss: 0.0020
# Epoch 72/200
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0020
# Epoch 73/200
# 8574/8574 [==============================] - 65s 8ms/step - loss: 0.0020
# Epoch 74/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 0.0020
# Epoch 75/200
# 8574/8574 [==============================] - 56s 6ms/step - loss: 0.0020
# Epoch 76/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0020
# Epoch 77/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0020
# Epoch 78/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0020
# Epoch 79/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0020
# Epoch 80/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0020
# Epoch 81/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0020
# Epoch 82/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0020
# Epoch 83/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0020
# Epoch 84/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0020
# Epoch 85/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0020
# Epoch 86/200
# 8574/8574 [==============================] - 70s 8ms/step - loss: 0.0020
# Epoch 87/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 0.0020
# Epoch 88/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0020
# Epoch 89/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0020
# Epoch 90/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0020
# Epoch 91/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 92/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0019
# Epoch 93/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 94/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 95/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 96/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 97/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0019
# Epoch 98/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 99/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0019
# Epoch 100/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 101/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 102/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 103/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 104/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 105/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 106/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 107/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 108/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 109/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 110/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 111/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0019
# Epoch 112/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0019
# Epoch 113/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 114/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0019
# Epoch 115/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0019
# Epoch 116/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 117/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0019
# Epoch 118/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0019
# Epoch 119/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 120/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 121/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 122/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 123/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 124/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 125/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 126/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 127/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0018
# Epoch 128/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 129/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 130/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 131/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 132/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 133/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 134/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 135/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 136/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 137/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 138/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 139/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 140/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0018
# Epoch 141/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 142/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 143/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 144/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 145/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 146/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 147/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 148/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 149/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 150/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0018
# Epoch 151/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 152/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0018
# Epoch 153/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 154/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 155/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 156/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 157/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 158/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0018
# Epoch 159/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0018
# Epoch 160/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 161/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 162/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 163/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 164/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 165/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 166/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 167/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 168/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 169/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 170/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 171/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 172/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 173/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 174/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 175/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 176/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 177/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 178/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0017
# Epoch 179/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 180/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 181/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 182/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 183/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 184/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 185/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 0.0017
# Epoch 186/200
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 187/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 188/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 189/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 190/200
# 8574/8574 [==============================] - 56s 6ms/step - loss: 0.0017
# Epoch 191/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017
# Epoch 192/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0017
# Epoch 193/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0017
# Epoch 194/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0017
# Epoch 195/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0017
# Epoch 196/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0017
# Epoch 197/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0017
# Epoch 198/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0017
# Epoch 199/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0017
# Epoch 200/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0017

# %%
lstm_model_dbp = bp_lstm_model(merged_train_features, merged_train_dbp)
# Out:
# Epoch 1/200
# 8574/8574 [==============================] - 67s 7ms/step - loss: 0.0032
# Epoch 2/200
# 8574/8574 [==============================] - 62s 7ms/step - loss: 0.0028
# Epoch 3/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0026
# Epoch 4/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0023
# Epoch 5/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 0.0021
# Epoch 6/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0020
# Epoch 7/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0018
# Epoch 8/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0017
# Epoch 9/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0016
# Epoch 10/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 0.0015
# Epoch 11/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0014
# Epoch 12/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0013
# Epoch 13/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0013
# Epoch 14/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 0.0013
# Epoch 15/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0012
# Epoch 16/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 0.0012
# Epoch 17/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0011
# Epoch 18/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 0.0011
# Epoch 19/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 0.0011
# Epoch 20/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 0.0011
# Epoch 21/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 0.0011
# Epoch 22/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 0.0010
# Epoch 23/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 0.0010
# Epoch 24/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 0.0010
# Epoch 25/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 0.0010
# Epoch 26/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 9.8655e-04
# Epoch 27/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 9.7716e-04
# Epoch 28/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 9.6524e-04
# Epoch 29/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 9.5600e-04
# Epoch 30/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 9.5000e-04
# Epoch 31/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 9.3368e-04
# Epoch 32/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 9.2652e-04
# Epoch 33/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 9.2479e-04
# Epoch 34/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 9.0718e-04
# Epoch 35/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 8.9969e-04
# Epoch 36/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 8.8600e-04
# Epoch 37/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.9073e-04
# Epoch 38/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 8.8080e-04
# Epoch 39/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 8.7917e-04
# Epoch 40/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.6509e-04
# Epoch 41/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.6298e-04
# Epoch 42/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.5539e-04
# Epoch 43/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.5045e-04
# Epoch 44/200
# 8574/8574 [==============================] - 56s 6ms/step - loss: 8.5019e-04
# Epoch 45/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 8.4043e-04
# Epoch 46/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 8.3186e-04
# Epoch 47/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 8.2760e-04
# Epoch 48/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 8.2330e-04
# Epoch 49/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 8.2023e-04
# Epoch 50/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 8.1743e-04
# Epoch 51/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 8.1170e-04
# Epoch 52/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 7.9665e-04
# Epoch 53/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 8.0060e-04
# Epoch 54/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 7.9680e-04
# Epoch 55/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 7.9778e-04
# Epoch 56/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 7.8943e-04
# Epoch 57/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 7.8055e-04
# Epoch 58/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 7.7864e-04
# Epoch 59/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 7.7840e-04
# Epoch 60/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 7.7123e-04
# Epoch 61/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 7.6761e-04
# Epoch 62/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 7.5968e-04
# Epoch 63/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 7.6128e-04
# Epoch 64/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 7.6088e-04
# Epoch 65/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 7.5721e-04
# Epoch 66/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 7.5114e-04
# Epoch 67/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 7.4897e-04
# Epoch 68/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 7.4370e-04
# Epoch 69/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 7.4739e-04
# Epoch 70/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 7.3679e-04
# Epoch 71/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.3936e-04
# Epoch 72/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.3292e-04
# Epoch 73/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 7.3186e-04
# Epoch 74/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 7.3193e-04
# Epoch 75/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 7.2972e-04
# Epoch 76/200
# 8574/8574 [==============================] - 69s 8ms/step - loss: 7.1893e-04
# Epoch 77/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 7.1699e-04
# Epoch 78/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 7.2167e-04
# Epoch 79/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 7.1845e-04
# Epoch 80/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.1646e-04
# Epoch 81/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.1225e-04
# Epoch 82/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 7.0739e-04
# Epoch 83/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.0836e-04
# Epoch 84/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 7.0411e-04
# Epoch 85/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 7.0116e-04
# Epoch 86/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.9067e-04
# Epoch 87/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 7.0012e-04
# Epoch 88/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.9261e-04
# Epoch 89/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.8985e-04
# Epoch 90/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.9682e-04
# Epoch 91/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.9230e-04
# Epoch 92/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.8288e-04
# Epoch 93/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.8728e-04
# Epoch 94/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.8202e-04
# Epoch 95/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.8013e-04
# Epoch 96/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.7750e-04
# Epoch 97/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 6.7548e-04
# Epoch 98/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.7092e-04
# Epoch 99/200
# 8574/8574 [==============================] - 48s 6ms/step - loss: 6.7519e-04
# Epoch 100/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 6.7403e-04
# Epoch 101/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.6546e-04
# Epoch 102/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 6.6535e-04
# Epoch 103/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.5971e-04
# Epoch 104/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.6337e-04
# Epoch 105/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.6552e-04
# Epoch 106/200
# 8574/8574 [==============================] - 49s 6ms/step - loss: 6.6836e-04
# Epoch 107/200
# 8574/8574 [==============================] - 50s 6ms/step - loss: 6.5952e-04
# Epoch 108/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.5666e-04
# Epoch 109/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.5732e-04
# Epoch 110/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.5491e-04
# Epoch 111/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4585e-04
# Epoch 112/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.5253e-04
# Epoch 113/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4864e-04
# Epoch 114/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 6.4463e-04
# Epoch 115/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4127e-04
# Epoch 116/200
# 8574/8574 [==============================] - 51s 6ms/step - loss: 6.4671e-04
# Epoch 117/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4085e-04
# Epoch 118/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4275e-04
# Epoch 119/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.4230e-04
# Epoch 120/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 6.4071e-04
# Epoch 121/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3837e-04
# Epoch 122/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3999e-04
# Epoch 123/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.3193e-04
# Epoch 124/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3305e-04
# Epoch 125/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3791e-04
# Epoch 126/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3240e-04
# Epoch 127/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3274e-04
# Epoch 128/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.2553e-04
# Epoch 129/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.3118e-04
# Epoch 130/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.2761e-04
# Epoch 131/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.2472e-04
# Epoch 132/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.1784e-04
# Epoch 133/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.2242e-04
# Epoch 134/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.2247e-04
# Epoch 135/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.1233e-04
# Epoch 136/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.1649e-04
# Epoch 137/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 6.1332e-04
# Epoch 138/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 6.1372e-04
# Epoch 139/200
# 8574/8574 [==============================] - 55s 6ms/step - loss: 6.1101e-04
# Epoch 140/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.1053e-04
# Epoch 141/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.1186e-04
# Epoch 142/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0970e-04
# Epoch 143/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 6.1057e-04
# Epoch 144/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0636e-04
# Epoch 145/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.1126e-04
# Epoch 146/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0908e-04
# Epoch 147/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0866e-04
# Epoch 148/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0116e-04
# Epoch 149/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0228e-04
# Epoch 150/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0016e-04
# Epoch 151/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 6.0038e-04
# Epoch 152/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9596e-04
# Epoch 153/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.9606e-04
# Epoch 154/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9521e-04
# Epoch 155/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9471e-04
# Epoch 156/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9286e-04
# Epoch 157/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9269e-04
# Epoch 158/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9557e-04
# Epoch 159/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.9011e-04
# Epoch 160/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8789e-04
# Epoch 161/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.9002e-04
# Epoch 162/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8756e-04
# Epoch 163/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8602e-04
# Epoch 164/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.8762e-04
# Epoch 165/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8522e-04
# Epoch 166/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8508e-04
# Epoch 167/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 5.8821e-04
# Epoch 168/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8373e-04
# Epoch 169/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.8330e-04
# Epoch 170/200
# 8574/8574 [==============================] - 57s 7ms/step - loss: 5.8446e-04
# Epoch 171/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 5.8146e-04
# Epoch 172/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 5.7829e-04
# Epoch 173/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7357e-04
# Epoch 174/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7249e-04
# Epoch 175/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.8280e-04
# Epoch 176/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7438e-04
# Epoch 177/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 5.7426e-04
# Epoch 178/200
# 8574/8574 [==============================] - 58s 7ms/step - loss: 5.7438e-04
# Epoch 179/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 5.7422e-04
# Epoch 180/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.7425e-04
# Epoch 181/200
# 8574/8574 [==============================] - 53s 6ms/step - loss: 5.7205e-04
# Epoch 182/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7762e-04
# Epoch 183/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.6667e-04
# Epoch 184/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.6961e-04
# Epoch 185/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.6676e-04
# Epoch 186/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7141e-04
# Epoch 187/200
# 8574/8574 [==============================] - 52s 6ms/step - loss: 5.7108e-04
# Epoch 188/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 5.6564e-04
# Epoch 189/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 5.6813e-04
# Epoch 190/200
# 8574/8574 [==============================] - 74s 9ms/step - loss: 5.6125e-04
# Epoch 191/200
# 8574/8574 [==============================] - 61s 7ms/step - loss: 5.6270e-04
# Epoch 192/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 5.6308e-04
# Epoch 193/200
# 8574/8574 [==============================] - 54s 6ms/step - loss: 5.6041e-04
# Epoch 194/200
# 8574/8574 [==============================] - 56s 6ms/step - loss: 5.6374e-04
# Epoch 195/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 5.5973e-04
# Epoch 196/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 5.6454e-04
# Epoch 197/200
# 8574/8574 [==============================] - 56s 7ms/step - loss: 5.5777e-04
# Epoch 198/200
# 8574/8574 [==============================] - 59s 7ms/step - loss: 5.6103e-04
# Epoch 199/200
# 8574/8574 [==============================] - 62s 7ms/step - loss: 5.5971e-04
# Epoch 200/200
# 8574/8574 [==============================] - 60s 7ms/step - loss: 5.5740e-04

# %%
gru_model_sbp = gru_model(merged_train_features, merged_train_sbp)
gru_model_dbp = gru_model(merged_train_features, merged_train_dbp)
# Out:
# Epoch 1/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 0.0076
# Epoch 2/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0063
# Epoch 3/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0055
# Epoch 4/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 0.0047
# Epoch 5/300
# 8574/8574 [==============================] - 81s 10ms/step - loss: 0.0041
# Epoch 6/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0037
# Epoch 7/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0034
# Epoch 8/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0032
# Epoch 9/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0030
# Epoch 10/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0029
# Epoch 11/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0027
# Epoch 12/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 0.0026
# Epoch 13/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0026
# Epoch 14/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0025
# Epoch 15/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0024
# Epoch 16/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0024
# Epoch 17/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0023
# Epoch 18/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0023
# Epoch 19/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 0.0022
# Epoch 20/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0022
# Epoch 21/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0022
# Epoch 22/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 0.0021
# Epoch 23/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0021
# Epoch 24/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 0.0021
# Epoch 25/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0021
# Epoch 26/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0020
# Epoch 27/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 0.0020
# Epoch 28/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0020
# Epoch 29/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0020
# Epoch 30/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 0.0020
# Epoch 31/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0020
# Epoch 32/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0019
# Epoch 33/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0019
# Epoch 34/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0019
# Epoch 35/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0019
# Epoch 36/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0019
# Epoch 37/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0019
# Epoch 38/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0019
# Epoch 39/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 40/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 41/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 42/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 43/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 44/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 45/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 46/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 47/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 48/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 49/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 50/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 51/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 52/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 53/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0018
# Epoch 54/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 55/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 56/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 57/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 58/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 59/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0017
# Epoch 60/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0017
# Epoch 61/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 62/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 63/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 64/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 65/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 66/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 67/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0017
# Epoch 68/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0017
# Epoch 69/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 0.0017
# Epoch 70/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0017
# Epoch 71/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0017
# Epoch 72/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0017
# Epoch 73/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 0.0016
# Epoch 74/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 75/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 76/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 77/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 78/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 79/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 80/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 81/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 82/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 0.0016
# Epoch 83/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 0.0016
# Epoch 84/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 85/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 0.0016
# Epoch 86/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 87/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 0.0016
# Epoch 88/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0016
# Epoch 89/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0016
# Epoch 90/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 0.0016
# Epoch 91/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0016
# Epoch 92/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0016
# Epoch 93/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0016
# Epoch 94/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 95/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 96/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 97/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0016
# Epoch 98/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 99/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 100/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0016
# Epoch 101/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 102/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 103/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 104/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 105/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 106/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0016
# Epoch 107/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 108/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 109/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 110/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 111/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 112/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 113/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 114/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 115/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 116/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 117/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 118/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 119/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 120/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 121/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 122/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 123/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 124/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 125/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 126/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 127/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 128/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 129/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 130/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 131/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 132/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 133/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 134/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 135/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 136/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 137/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 138/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 139/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 140/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 141/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 142/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 143/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 144/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 145/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 146/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 147/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 148/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 149/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 150/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 151/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 152/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 153/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 154/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 155/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 156/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 157/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 158/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 0.0015
# Epoch 159/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 160/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 161/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 162/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 163/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 164/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 165/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 166/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 167/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 168/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 169/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 170/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 171/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 172/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 173/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 174/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 175/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 176/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 177/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 178/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 179/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 180/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 181/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0014
# Epoch 182/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 183/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 184/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 185/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 186/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 187/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 188/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 189/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 190/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0014
# Epoch 191/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 192/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 193/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0015
# Epoch 194/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 195/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 196/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0015
# Epoch 197/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0014
# Epoch 198/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 199/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0014
# Epoch 200/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 201/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 202/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0014
# Epoch 203/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 204/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 0.0014
# Epoch 205/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 206/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 0.0014
# Epoch 207/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 208/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 209/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 210/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 211/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 212/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 213/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 214/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 215/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 216/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 217/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 218/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 219/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 220/300
# 8574/8574 [==============================] - 70s 8ms/step - loss: 0.0014
# Epoch 221/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 222/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 223/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 224/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 225/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 226/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 227/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 228/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 229/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 230/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 231/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 232/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 233/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 234/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 235/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 236/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 237/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 238/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 239/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 240/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 241/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 242/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 243/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 244/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 245/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 246/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 247/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 248/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 249/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 250/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 251/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 252/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 253/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 254/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 255/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 256/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 257/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 258/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 259/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 260/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 261/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 262/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 263/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 264/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 265/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 266/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 267/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 268/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 269/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 270/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 271/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 272/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 273/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 274/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 275/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 276/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 277/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 278/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 279/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 280/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 281/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 282/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 283/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 284/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 285/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 286/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 287/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 288/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 289/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 290/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 291/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 292/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 293/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 294/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 295/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 296/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 297/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 298/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 299/300
# 8574/8574 [==============================] - 68s 8ms/step - loss: 0.0014
# Epoch 300/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0014
# Epoch 1/300
# 8574/8574 [==============================] - 95s 10ms/step - loss: 0.0031
# Epoch 2/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0028
# Epoch 3/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 0.0025
# Epoch 4/300
# 8574/8574 [==============================] - 70s 8ms/step - loss: 0.0023
# Epoch 5/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0020
# Epoch 6/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0018
# Epoch 7/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 0.0016
# Epoch 8/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 0.0015
# Epoch 9/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 0.0014
# Epoch 10/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0013
# Epoch 11/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0013
# Epoch 12/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0012
# Epoch 13/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 0.0012
# Epoch 14/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0012
# Epoch 15/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0011
# Epoch 16/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0011
# Epoch 17/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0011
# Epoch 18/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0011
# Epoch 19/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0011
# Epoch 20/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0010
# Epoch 21/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0010
# Epoch 22/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0010
# Epoch 23/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0010
# Epoch 24/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 0.0010
# Epoch 25/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.8439e-04
# Epoch 26/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 9.7827e-04
# Epoch 27/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.6833e-04
# Epoch 28/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.6083e-04
# Epoch 29/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.5556e-04
# Epoch 30/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.4035e-04
# Epoch 31/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.3591e-04
# Epoch 32/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.3973e-04
# Epoch 33/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.2864e-04
# Epoch 34/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.1762e-04
# Epoch 35/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.1630e-04
# Epoch 36/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 9.0641e-04
# Epoch 37/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.9893e-04
# Epoch 38/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.9981e-04
# Epoch 39/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.9106e-04
# Epoch 40/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.8660e-04
# Epoch 41/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.8763e-04
# Epoch 42/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.7479e-04
# Epoch 43/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.7094e-04
# Epoch 44/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.6787e-04
# Epoch 45/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.6645e-04
# Epoch 46/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.5762e-04
# Epoch 47/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.5780e-04
# Epoch 48/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.5103e-04
# Epoch 49/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.5489e-04
# Epoch 50/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.4289e-04
# Epoch 51/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.4993e-04
# Epoch 52/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.4294e-04
# Epoch 53/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.3599e-04
# Epoch 54/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.3893e-04
# Epoch 55/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.2964e-04
# Epoch 56/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.3166e-04
# Epoch 57/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.2805e-04
# Epoch 58/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.1955e-04
# Epoch 59/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.2183e-04
# Epoch 60/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.2243e-04
# Epoch 61/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.1787e-04
# Epoch 62/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.1720e-04
# Epoch 63/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.0913e-04
# Epoch 64/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.0488e-04
# Epoch 65/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.1090e-04
# Epoch 66/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 8.1387e-04
# Epoch 67/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9915e-04
# Epoch 68/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.0642e-04
# Epoch 69/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 8.0194e-04
# Epoch 70/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9846e-04
# Epoch 71/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9663e-04
# Epoch 72/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9648e-04
# Epoch 73/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9485e-04
# Epoch 74/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9136e-04
# Epoch 75/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.8616e-04
# Epoch 76/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9151e-04
# Epoch 77/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7981e-04
# Epoch 78/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.8021e-04
# Epoch 79/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.9309e-04
# Epoch 80/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7868e-04
# Epoch 81/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7610e-04
# Epoch 82/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7484e-04
# Epoch 83/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7452e-04
# Epoch 84/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.7797e-04
# Epoch 85/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6494e-04
# Epoch 86/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6983e-04
# Epoch 87/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6593e-04
# Epoch 88/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.7206e-04
# Epoch 89/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6777e-04
# Epoch 90/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6536e-04
# Epoch 91/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.6240e-04
# Epoch 92/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5776e-04
# Epoch 93/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6243e-04
# Epoch 94/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.4958e-04
# Epoch 95/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5422e-04
# Epoch 96/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6097e-04
# Epoch 97/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5684e-04
# Epoch 98/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5609e-04
# Epoch 99/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5285e-04
# Epoch 100/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.5177e-04
# Epoch 101/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.5001e-04
# Epoch 102/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5350e-04
# Epoch 103/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.6144e-04
# Epoch 104/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.4484e-04
# Epoch 105/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5036e-04
# Epoch 106/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.4187e-04
# Epoch 107/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.5133e-04
# Epoch 108/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3972e-04
# Epoch 109/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.4550e-04
# Epoch 110/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3285e-04
# Epoch 111/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3732e-04
# Epoch 112/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.4203e-04
# Epoch 113/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.4425e-04
# Epoch 114/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.3504e-04
# Epoch 115/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 7.3116e-04
# Epoch 116/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3768e-04
# Epoch 117/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3499e-04
# Epoch 118/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3091e-04
# Epoch 119/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.3886e-04
# Epoch 120/300
# 8574/8574 [==============================] - 401s 47ms/step - loss: 7.3521e-04
# Epoch 121/300
# 8574/8574 [==============================] - 695s 81ms/step - loss: 7.3361e-04
# Epoch 122/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.2547e-04
# Epoch 123/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.2717e-04
# Epoch 124/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 7.3185e-04
# Epoch 125/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.2887e-04
# Epoch 126/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 7.2481e-04
# Epoch 127/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 7.2623e-04
# Epoch 128/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 7.2559e-04
# Epoch 129/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 7.2411e-04
# Epoch 130/300
# 8574/8574 [==============================] - 69s 8ms/step - loss: 7.1920e-04
# Epoch 131/300
# 8574/8574 [==============================] - 71s 8ms/step - loss: 7.2293e-04
# Epoch 132/300
# 8574/8574 [==============================] - 95s 11ms/step - loss: 7.2902e-04
# Epoch 133/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 7.2647e-04
# Epoch 134/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.2290e-04
# Epoch 135/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.2147e-04
# Epoch 136/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.2178e-04
# Epoch 137/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.2765e-04
# Epoch 138/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.2269e-04
# Epoch 139/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.1701e-04
# Epoch 140/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.2747e-04
# Epoch 141/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.2204e-04
# Epoch 142/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.1351e-04
# Epoch 143/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.1514e-04
# Epoch 144/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.1692e-04
# Epoch 145/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.0837e-04
# Epoch 146/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.1330e-04
# Epoch 147/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.1774e-04
# Epoch 148/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.1096e-04
# Epoch 149/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.1282e-04
# Epoch 150/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.1191e-04
# Epoch 151/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.0632e-04
# Epoch 152/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.1098e-04
# Epoch 153/300
# 8574/8574 [==============================] - 100s 12ms/step - loss: 7.1374e-04
# Epoch 154/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 7.0992e-04
# Epoch 155/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 7.1430e-04
# Epoch 156/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 7.0413e-04
# Epoch 157/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0827e-04
# Epoch 158/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0776e-04
# Epoch 159/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 7.1779e-04
# Epoch 160/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0743e-04
# Epoch 161/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.1311e-04
# Epoch 162/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 7.0656e-04
# Epoch 163/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.0679e-04
# Epoch 164/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0525e-04
# Epoch 165/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.1142e-04
# Epoch 166/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 7.0217e-04
# Epoch 167/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 7.0561e-04
# Epoch 168/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.9939e-04
# Epoch 169/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.9587e-04
# Epoch 170/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0319e-04
# Epoch 171/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.9888e-04
# Epoch 172/300
# 8574/8574 [==============================] - 84s 10ms/step - loss: 7.0030e-04
# Epoch 173/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.9316e-04
# Epoch 174/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 7.0033e-04
# Epoch 175/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.9357e-04
# Epoch 176/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.9842e-04
# Epoch 177/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 7.0278e-04
# Epoch 178/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 7.0176e-04
# Epoch 179/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 7.0077e-04
# Epoch 180/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 7.0040e-04
# Epoch 181/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 6.9122e-04
# Epoch 182/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 6.9503e-04
# Epoch 183/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 7.0049e-04
# Epoch 184/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.9135e-04
# Epoch 185/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.8916e-04
# Epoch 186/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.9663e-04
# Epoch 187/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.9346e-04
# Epoch 188/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 6.9120e-04
# Epoch 189/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 6.8859e-04
# Epoch 190/300
# 8574/8574 [==============================] - 72s 8ms/step - loss: 6.9525e-04
# Epoch 191/300
# 8574/8574 [==============================] - 73s 8ms/step - loss: 6.8981e-04
# Epoch 192/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 6.8723e-04
# Epoch 193/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 6.9032e-04
# Epoch 194/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 6.9260e-04
# Epoch 195/300
# 8574/8574 [==============================] - 73s 9ms/step - loss: 6.9130e-04
# Epoch 196/300
# 8574/8574 [==============================] - 74s 9ms/step - loss: 6.9074e-04
# Epoch 197/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 6.9303e-04
# Epoch 198/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.8839e-04
# Epoch 199/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.8327e-04
# Epoch 200/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.8929e-04
# Epoch 201/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.8006e-04
# Epoch 202/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.9736e-04
# Epoch 203/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 6.9606e-04
# Epoch 204/300
# 8574/8574 [==============================] - 90s 11ms/step - loss: 6.8718e-04
# Epoch 205/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.8400e-04
# Epoch 206/300
# 8574/8574 [==============================] - 107s 12ms/step - loss: 6.8621e-04
# Epoch 207/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.8517e-04
# Epoch 208/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.8207e-04
# Epoch 209/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7572e-04
# Epoch 210/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 6.9107e-04
# Epoch 211/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.7662e-04
# Epoch 212/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 6.8380e-04
# Epoch 213/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.7796e-04
# Epoch 214/300
# 8574/8574 [==============================] - 75s 9ms/step - loss: 6.8060e-04
# Epoch 215/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.8020e-04
# Epoch 216/300
# 8574/8574 [==============================] - 76s 9ms/step - loss: 6.7925e-04
# Epoch 217/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.8461e-04
# Epoch 218/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.8954e-04
# Epoch 219/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.7801e-04
# Epoch 220/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 6.7799e-04
# Epoch 221/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.7327e-04
# Epoch 222/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.8410e-04
# Epoch 223/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.8109e-04
# Epoch 224/300
# 8574/8574 [==============================] - 84s 10ms/step - loss: 6.7973e-04
# Epoch 225/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.8754e-04
# Epoch 226/300
# 8574/8574 [==============================] - 85s 10ms/step - loss: 6.8034e-04
# Epoch 227/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 6.8304e-04
# Epoch 228/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.7258e-04
# Epoch 229/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7477e-04
# Epoch 230/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.7587e-04
# Epoch 231/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.8735e-04
# Epoch 232/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7431e-04
# Epoch 233/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.8425e-04
# Epoch 234/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7881e-04
# Epoch 235/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.8352e-04
# Epoch 236/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7540e-04
# Epoch 237/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7250e-04
# Epoch 238/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7491e-04
# Epoch 239/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7308e-04
# Epoch 240/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.6601e-04
# Epoch 241/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7375e-04
# Epoch 242/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7421e-04
# Epoch 243/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.8278e-04
# Epoch 244/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.6658e-04
# Epoch 245/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7264e-04
# Epoch 246/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.7354e-04
# Epoch 247/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.8461e-04
# Epoch 248/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.7689e-04
# Epoch 249/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7327e-04
# Epoch 250/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.7537e-04
# Epoch 251/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.7935e-04
# Epoch 252/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7426e-04
# Epoch 253/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.6759e-04
# Epoch 254/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.6941e-04
# Epoch 255/300
# 8574/8574 [==============================] - 84s 10ms/step - loss: 6.7209e-04
# Epoch 256/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7006e-04
# Epoch 257/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.7120e-04
# Epoch 258/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.7389e-04
# Epoch 259/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.6789e-04
# Epoch 260/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.7150e-04
# Epoch 261/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.7960e-04
# Epoch 262/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.7095e-04
# Epoch 263/300
# 8574/8574 [==============================] - 97s 11ms/step - loss: 6.7171e-04
# Epoch 264/300
# 8574/8574 [==============================] - 92s 11ms/step - loss: 6.6608e-04
# Epoch 265/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.7277e-04
# Epoch 266/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.6992e-04
# Epoch 267/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.6266e-04
# Epoch 268/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 6.6903e-04
# Epoch 269/300
# 8574/8574 [==============================] - 82s 10ms/step - loss: 6.6765e-04
# Epoch 270/300
# 8574/8574 [==============================] - 86s 10ms/step - loss: 6.7388e-04
# Epoch 271/300
# 8574/8574 [==============================] - 84s 10ms/step - loss: 6.6491e-04
# Epoch 272/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.7791e-04
# Epoch 273/300
# 8574/8574 [==============================] - 84s 10ms/step - loss: 6.6959e-04
# Epoch 274/300
# 8574/8574 [==============================] - 90s 11ms/step - loss: 6.7274e-04
# Epoch 275/300
# 8574/8574 [==============================] - 97s 11ms/step - loss: 6.6531e-04
# Epoch 276/300
# 8574/8574 [==============================] - 104s 12ms/step - loss: 6.6892e-04
# Epoch 277/300
# 8574/8574 [==============================] - 92s 11ms/step - loss: 6.7632e-04
# Epoch 278/300
# 8574/8574 [==============================] - 91s 11ms/step - loss: 6.7030e-04
# Epoch 279/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.6733e-04
# Epoch 280/300
# 8574/8574 [==============================] - 96s 11ms/step - loss: 6.7194e-04
# Epoch 281/300
# 8574/8574 [==============================] - 95s 11ms/step - loss: 6.7116e-04
# Epoch 282/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 6.6426e-04
# Epoch 283/300
# 8574/8574 [==============================] - 89s 10ms/step - loss: 6.6500e-04
# Epoch 284/300
# 8574/8574 [==============================] - 94s 11ms/step - loss: 6.6826e-04
# Epoch 285/300
# 8574/8574 [==============================] - 91s 11ms/step - loss: 6.6391e-04
# Epoch 286/300
# 8574/8574 [==============================] - 94s 11ms/step - loss: 6.6801e-04
# Epoch 287/300
# 8574/8574 [==============================] - 92s 11ms/step - loss: 6.6299e-04
# Epoch 288/300
# 8574/8574 [==============================] - 90s 11ms/step - loss: 6.5742e-04
# Epoch 289/300
# 8574/8574 [==============================] - 87s 10ms/step - loss: 6.6323e-04
# Epoch 290/300
# 8574/8574 [==============================] - 83s 10ms/step - loss: 6.6421e-04
# Epoch 291/300
# 8574/8574 [==============================] - 77s 9ms/step - loss: 6.5486e-04
# Epoch 292/300
# 8574/8574 [==============================] - 78s 9ms/step - loss: 6.6226e-04
# Epoch 293/300
# 8574/8574 [==============================] - 79s 9ms/step - loss: 6.5520e-04
# Epoch 294/300
# 8574/8574 [==============================] - 88s 10ms/step - loss: 6.5941e-04
# Epoch 295/300
# 8574/8574 [==============================] - 80s 9ms/step - loss: 6.7432e-04
# Epoch 296/300
# 8574/8574 [==============================] - 81s 9ms/step - loss: 6.7077e-04
# Epoch 297/300
# 8574/8574 [==============================] - 99s 12ms/step - loss: 6.6262e-04
# Epoch 298/300
# 8574/8574 [==============================] - 91s 11ms/step - loss: 6.7040e-04
# Epoch 299/300
# 8574/8574 [==============================] - 102s 12ms/step - loss: 6.7380e-04
# Epoch 300/300
# 8574/8574 [==============================] - 93s 11ms/step - loss: 6.6722e-04

# %%
# too short test[6, 19]

# %%
# eveluate the model
mae_sbp_lstms = []
rmse_sbp_lstms = []
mae_sbp_grus = []
rmse_sbp_grus = []
mae_dbp_lstms = []
rmse_dbp_lstms = []
mae_dbp_grus = []
rmse_dbp_grus = []
for i in range(1):#len(test_sbp)
    X_test, sbp_test = create_sequences(pd.DataFrame(test_features[i].T), pd.DataFrame(test_sbp[i]))
    X_test, sbp_ori_test = create_sequences(pd.DataFrame(test_features[i].T), pd.DataFrame(test_sbp_ori[i]))
    X_test, dbp_test = create_sequences(pd.DataFrame(test_features[i].T), pd.DataFrame(test_dbp[i]))
    X_test, dbp_ori_test = create_sequences(pd.DataFrame(test_features[i].T), pd.DataFrame(test_dbp_ori[i]))
    sbp_pred_lstm = lstm_model_sbp.predict(X_test)
    sbp_ori_pred_lstm = sbp_pred_lstm * 250
    mae_sbp_lstm = np.mean(np.abs(sbp_ori_test - sbp_ori_pred_lstm))
    rmse_sbp_lstm = np.sqrt(np.mean((sbp_ori_test - sbp_ori_pred_lstm)**2))
    dbp_pred_lstm = lstm_model_dbp.predict(X_test)
    dbp_ori_pred_lstm = dbp_pred_lstm * 250
    mae_dbp_lstm = np.mean(np.abs(dbp_ori_test - dbp_ori_pred_lstm))
    rmse_dbp_lstm = np.sqrt(np.mean((dbp_ori_test - dbp_ori_pred_lstm)**2))
    print("MAE:", mae_sbp_lstm)
    print("MAE:", mae_dbp_lstm)
    print("RMSE:", rmse_sbp_lstm)
    print("RMSE:", rmse_dbp_lstm)
    
    print(i)
    show_two(sbp_ori_test, sbp_ori_pred_lstm)
    show_two(dbp_ori_test, dbp_ori_pred_lstm)
    mae_sbp_lstms.append(mae_sbp_lstm)
    rmse_sbp_lstms.append(rmse_sbp_lstm)
    mae_dbp_lstms.append(mae_dbp_lstm)
    rmse_dbp_lstms.append(rmse_dbp_lstm)
    sbp_pred_gru = gru_model_sbp.predict(X_test)
    sbp_ori_pred_gru = sbp_pred_gru * 250
    mae_sbp_gru = np.mean(np.abs(sbp_ori_test - sbp_ori_pred_gru))
    rmse_sbp_gru = np.sqrt(np.mean((sbp_ori_test - sbp_ori_pred_gru)**2))
    dbp_pred_gru = gru_model_dbp.predict(X_test)
    dbp_ori_pred_gru = dbp_pred_gru * 250
    mae_dbp_gru = np.mean(np.abs(dbp_ori_test - dbp_ori_pred_gru))
    rmse_dbp_gru = np.sqrt(np.mean((dbp_ori_test - dbp_ori_pred_gru)**2))
    print("MAE:", mae_sbp_gru)
    print("MAE:", mae_dbp_gru)
    print("RMSE:", rmse_sbp_gru)
    print("RMSE:", rmse_dbp_gru)
    show_two(sbp_ori_test, sbp_ori_pred_gru)
    show_two(dbp_ori_test, dbp_ori_pred_gru) 
    mae_sbp_grus.append(mae_sbp_gru)
    rmse_sbp_grus.append(rmse_sbp_gru)
    mae_dbp_grus.append(mae_dbp_gru)
    rmse_dbp_grus.append(rmse_dbp_gru)
# Out:
# 6/6 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 5ms/step
# MAE: 5.929775256681008
# MAE: 2.286287855103314
# RMSE: 8.883184784632364
# RMSE: 3.482658374353229
# 0
# 6/6 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 13ms/step
# MAE: 6.068243086170831
# MAE: 2.222959123029467
# RMSE: 9.99546394600078
# RMSE: 3.895398592552222

# %%
print(np.mean(mae_sbp_lstms), np.mean(rmse_sbp_lstms), np.mean(mae_dbp_lstms), np.mean(rmse_dbp_lstms))
print(np.mean(mae_sbp_grus), np.mean(rmse_sbp_grus), np.mean(mae_dbp_grus), np.mean(rmse_dbp_grus))
# Out:
# 14.131894948856623 18.71245535284791 7.3703628627018976 10.247684813704419
# 11.789928435196444 15.8053604490674 7.310609789315911 10.077430961452306

# %%
data = pd.read_csv('/Users/jinyanwei/Desktop/BP_Model/Jinyw_code/cc_mae/ppg_ecg_cc/wave_ppg_ecg80.csv')
data
# Out:
#     Unnamed: 0  Unnamed: 0.1  refbp_estbp_cc  refbp_ppg_cc  refbp_ecg_cc  \
# 0            0             0        0.937568      0.813409      0.185314
# 1            1             1        0.990031      0.960967      0.160424
# 2            2             2        0.996581      0.956650      0.160698
# 3            3             3        0.934680      0.881132      0.141013
# 4            4             4        0.996786      0.737095      0.239162
# ..         ...           ...             ...           ...           ...
# 75          65            65        0.985891      0.916188      0.099896
# 76          66            66        0.993160      0.942443      0.121789
# 77          67            67        0.998354      0.932171      0.122453
# 78          68            68        0.988117      0.836237      0.154363
# 79          69            69        0.995802      0.922436      0.051473
#
#     refbp_estbp_md  refbp_ppg_md  refbp_ecg_md  refbp_estbp_sd  refbp_ppg_sd  \
# 0         2.500662     93.527194     93.711294        7.701035     21.503012
# 1        -1.233475     90.623408     90.742034        3.080568     19.494784
# 2        -0.018602     92.930421     93.254354        2.080113     18.978637
# 3        -0.119799     93.023912     92.976199        7.722042     20.857934
# 4        -2.433375     93.997419     94.097317        3.149539     22.311534
# ..             ...           ...           ...             ...           ...
# 75       -0.991165     81.640597     81.775452        4.519990     26.660322
# 76        4.457423     88.275769     88.402296        6.734532     28.525313
# 77        0.405211     86.396094     86.559208        1.776982     28.914697
# 78        0.544283     68.991900     69.126652        2.574398     16.501442
# 79        0.619848     78.424437     78.576945        2.437393     23.427281
#
#     refbp_ecg_sd
# 0      21.617821
# 1      19.623261
# 2      19.113887
# 3      20.988221
# 4      22.390351
# ..           ...
# 75     26.798642
# 76     28.732828
# 77     29.063860
# 78     16.687604
# 79     23.651827
#
# [80 rows x 11 columns]

# %%
np.mean(data['refbp_estbp_cc']), np.mean(data['refbp_ppg_cc']), np.mean(data['refbp_ecg_cc'])
# Out:
# (0.9816451676065032, 0.8563992432074177, 0.06926337607811608)

# %%
data1 = pd.read_csv('/Users/jinyanwei/Desktop/BP_Model/Jinyw_code/cc_mae/ppg_ecg_cc/wave_ppg_ecg80.csv')
data1
